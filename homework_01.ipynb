# %%
print("Меня зовут Настя, и я готова страдать на курсе!")
# Out:
# Меня зовут Настя, и я готова страдать на курсе!

# %% [markdown]
# # Меня зовут Иванова Настя.
#  - Мне 24 года.
#  - Работаю в Транснефть Технологиях.
#  - закончила *бульбазавра* в 2022 году по специальности математик-программист в Плеханова

# %%
77 % 2
# Out:
# 1

# %%
22 / 2
# Out:
# 11.0

# %%
86 ** 7
# Out:
# 34792782221696

# %%
3686400 ** 0.5
# Out:
# 1920.0
